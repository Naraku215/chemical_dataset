# %%
import pandas as pd

# 读取数据
df = pd.read_parquet("train-00000-of-00001.parquet")

# 提取前 50 条数据
sample_df = df.head(50)

# 导出为 CSV 文件，加上 utf-8-sig 防止中文或化学特殊符号乱码
csv_file = "dataset_sample.csv"
sample_df.to_csv(csv_file, index=False, encoding='utf-8-sig')

print(f"已经将前 50 条数据导出为 {csv_file}，请用 Excel 或 WPS 打开查看！")
# Out:
# 已经将前 50 条数据导出为 dataset_sample.csv，请用 Excel 或 WPS 打开查看！
